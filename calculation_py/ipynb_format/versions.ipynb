# %% [markdown]
# # Package versions used

# %% [markdown]
# 18-04-2021 GC

# %%
import sys
sys.version
# Out:
# '3.8.8 (default, Apr 13 2021, 19:58:26) \n[GCC 7.3.0]'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.4'

# %%
import numpy
numpy.__version__
# Out:
# '1.20.1'

# %%
import pandas
pandas.__version__
# Out:
# '1.2.4'

# %%
import PIL
PIL.__version__
# Out:
# '8.2.0'

# %%
import scipy.stats
scipy.__version__
# Out:
# '1.6.2'

# %%
import seaborn
seaborn.__version__
# Out:
# '0.11.1'
