# %% [markdown]
# 30 March 2021 GC, R code to plot beeswarm

# %%
library("readxl")
library('data.table')
library("beeswarm")

# %%
read_CVC <- function(path_in) {
  dt <- read_excel(path_in)
  dt <- dt[ -c(1, 7)]
  bh5 <- subset(dt, Device=='BAHA5P')
  bh5 <- bh5[ -c(2)]
  bh5 <- bh5[, c(1, 4, 3, 2)]
  return(bh5)
}

# %%
path1 <- '/media/guido/LACIE/Cingle_Guido/Master/Headband/CVC_Sfront65_Nbest65.xlsx'

# %%
bh5 <- read_CVC(path1)
bh5
# Out:
# New names:
# * `` -> ...1
#    Study_ID AC&BC_path BC_path AC_path
# 1  21       0.79       0.89    0.79
# 2  48       0.79       0.88    0.79
# 3  52       0.79       0.89    0.79
# 4  54       0.80       0.86    0.79
# 5  55       0.79       0.88    0.79
# 6  56       0.81       0.88    0.79
# 7  57       0.79       0.87    0.79
# 8  58       0.79       0.90    0.79
# 9  59       0.79       0.87    0.79
# 10 60       0.81       0.88    0.79
# 11 61       0.79       0.87    0.79
# 12 62       0.82       0.87    0.79
# 13 63       0.80       0.88    0.79
# 14 64       0.79       0.88    0.79
# 15 65       0.79       0.88    0.79
# 16 66       0.79       0.89    0.79
# 17 67       0.79       0.86    0.79
# 18 68       0.79       0.88    0.79
# 19 69       0.80       0.88    0.79
# 20 70       0.79       0.90    0.79
# 21 71       0.79       0.86    0.79
# 22 72       0.79       0.88    0.79
# 23 73       0.79       0.87    0.79
# 24 74       0.79       0.88    0.79
# 25 75       0.85       0.88    0.79
# 26 76       0.79       0.88    0.79
# 27 77       0.79       0.89    0.79
# 28 78       0.79       0.89    0.79
# 29 79       0.79       0.88    0.79
# 30 80       0.80       0.87    0.79
# 31 81       0.79       0.86    0.79
# 32 82       0.79       0.88    0.79
# 33 83       0.80       0.87    0.79
# 34 84       0.79       0.87    0.79
# 35 85       0.79       0.88    0.79

# %%
bh5_long <- melt(setDT(bh5), id.vars = c('Study_ID'), 
                 value.name = 'CVC_score', variable.name = 'Sound_path')
bh5_long
# Out:
#     Study_ID Sound_path CVC_score
# 1   21       AC&BC_path 0.79
# 2   48       AC&BC_path 0.79
# 3   52       AC&BC_path 0.79
# 4   54       AC&BC_path 0.80
# 5   55       AC&BC_path 0.79
# 6   56       AC&BC_path 0.81
# 7   57       AC&BC_path 0.79
# 8   58       AC&BC_path 0.79
# 9   59       AC&BC_path 0.79
# 10  60       AC&BC_path 0.81
# 11  61       AC&BC_path 0.79
# 12  62       AC&BC_path 0.82
# 13  63       AC&BC_path 0.80
# 14  64       AC&BC_path 0.79
# 15  65       AC&BC_path 0.79
# 16  66       AC&BC_path 0.79
# 17  67       AC&BC_path 0.79
# 18  68       AC&BC_path 0.79
# 19  69       AC&BC_path 0.80
# 20  70       AC&BC_path 0.79
# 21  71       AC&BC_path 0.79
# 22  72       AC&BC_path 0.79
# 23  73       AC&BC_path 0.79
# 24  74       AC&BC_path 0.79
# 25  75       AC&BC_path 0.85
# 26  76       AC&BC_path 0.79
# 27  77       AC&BC_path 0.79
# 28  78       AC&BC_path 0.79
# 29  79       AC&BC_path 0.79
# 30  80       AC&BC_path 0.80
# ⋮   ⋮        ⋮          ⋮
# 76  56       AC_path    0.79
# 77  57       AC_path    0.79
# 78  58       AC_path    0.79
# 79  59       AC_path    0.79
# 80  60       AC_path    0.79
# 81  61       AC_path    0.79
# 82  62       AC_path    0.79
# 83  63       AC_path    0.79
# 84  64       AC_path    0.79
# 85  65       AC_path    0.79
# 86  66       AC_path    0.79
# 87  67       AC_path    0.79
# 88  68       AC_path    0.79
# 89  69       AC_path    0.79
# 90  70       AC_path    0.79
# 91  71       AC_path    0.79
# 92  72       AC_path    0.79
# 93  73       AC_path    0.79
# 94  74       AC_path    0.79
# 95  75       AC_path    0.79
# 96  76       AC_path    0.79
# 97  77       AC_path    0.79
# 98  78       AC_path    0.79
# 99  79       AC_path    0.79
# 100 80       AC_path    0.79
# 101 81       AC_path    0.79
# 102 82       AC_path    0.79
# 103 83       AC_path    0.79
# 104 84       AC_path    0.79
# 105 85       AC_path    0.79

# %%
clm = colnames(bh5)
sp = clm[-1]

# %%
ttl = "BAHA5P-group: CVC-score for the three sound paths, 
in the condition S in front and N at best-ear-side"
ColorBlind3  <- c("#E69F00", "#56B4E9", "#009E73")

beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, main = ttl, ylim=c(0.6, 1))
legend("bottomleft", legend = sp, title = "Sound-path", cex=1.1, pch = 16, col = ColorBlind3)
# Out:
# Plot with title “BAHA5P-group: CVC-score for the three sound paths,
# in the condition S in front and N at best-ear-side”

# %%
tiff("/home/guido/R/cingle/figures/CVC_Sf_Nbe.tiff", units="in", width=7, height=7, res=300)
beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, ylim=c(0.6, 1))
legend("bottomleft", legend = sp, title = "Sound-path", pch = 16, col = ColorBlind3, cex = 1.1)
dev.off()
# Out:
# png
#   2
