# %% [markdown]
# 30 March 2021 GC, R code to plot beeswarm

# %%
library("readxl")
library('data.table')
library("beeswarm")

# %%
read_CVC <- function(path_in) {
  dt <- read_excel(path_in)
  dt <- dt[ -c(1, 7)]
  bh5 <- subset(dt, Device=='BAHA5P')
  bh5 <- bh5[ -c(2)]
  bh5 <- bh5[, c(1, 4, 3, 2)]
  return(bh5)
}

# %%
path1 <- '/media/guido/LACIE/Cingle_Guido/Master/Headband/CVC_Sbcd65_Nfront65.xlsx'

# %%
bh5 <- read_CVC(path1)
bh5
# Out:
# New names:
# * `` -> ...1
#    Study_ID AC&BC_path BC_path AC_path
# 1  21       0.75       0.85    0.74
# 2  48       0.74       0.83    0.74
# 3  52       0.74       0.84    0.74
# 4  54       0.76       0.84    0.73
# 5  55       0.74       0.84    0.74
# 6  56       0.80       0.83    0.73
# 7  57       0.74       0.81    0.74
# 8  58       0.75       0.85    0.74
# 9  59       0.74       0.84    0.74
# 10 60       0.77       0.86    0.74
# 11 61       0.75       0.82    0.74
# 12 62       0.83       0.80    0.73
# 13 63       0.79       0.84    0.74
# 14 64       0.76       0.81    0.74
# 15 65       0.77       0.84    0.74
# 16 66       0.78       0.84    0.74
# 17 67       0.74       0.83    0.74
# 18 68       0.76       0.83    0.74
# 19 69       0.79       0.83    0.74
# 20 70       0.77       0.85    0.74
# 21 71       0.74       0.82    0.74
# 22 72       0.74       0.85    0.74
# 23 73       0.75       0.84    0.74
# 24 74       0.78       0.82    0.74
# 25 75       0.84       0.82    0.73
# 26 76       0.76       0.83    0.74
# 27 77       0.76       0.83    0.74
# 28 78       0.75       0.85    0.74
# 29 79       0.74       0.83    0.74
# 30 80       0.79       0.83    0.74
# 31 81       0.76       0.79    0.74
# 32 82       0.74       0.84    0.74
# 33 83       0.77       0.84    0.74
# 34 84       0.77       0.81    0.73
# 35 85       0.75       0.81    0.74

# %%
bh5_long <- melt(setDT(bh5), id.vars = c('Study_ID'), 
                 value.name = 'CVC_score', variable.name = 'Sound_path')
bh5_long
# Out:
#     Study_ID Sound_path CVC_score
# 1   21       AC&BC_path 0.75
# 2   48       AC&BC_path 0.74
# 3   52       AC&BC_path 0.74
# 4   54       AC&BC_path 0.76
# 5   55       AC&BC_path 0.74
# 6   56       AC&BC_path 0.80
# 7   57       AC&BC_path 0.74
# 8   58       AC&BC_path 0.75
# 9   59       AC&BC_path 0.74
# 10  60       AC&BC_path 0.77
# 11  61       AC&BC_path 0.75
# 12  62       AC&BC_path 0.83
# 13  63       AC&BC_path 0.79
# 14  64       AC&BC_path 0.76
# 15  65       AC&BC_path 0.77
# 16  66       AC&BC_path 0.78
# 17  67       AC&BC_path 0.74
# 18  68       AC&BC_path 0.76
# 19  69       AC&BC_path 0.79
# 20  70       AC&BC_path 0.77
# 21  71       AC&BC_path 0.74
# 22  72       AC&BC_path 0.74
# 23  73       AC&BC_path 0.75
# 24  74       AC&BC_path 0.78
# 25  75       AC&BC_path 0.84
# 26  76       AC&BC_path 0.76
# 27  77       AC&BC_path 0.76
# 28  78       AC&BC_path 0.75
# 29  79       AC&BC_path 0.74
# 30  80       AC&BC_path 0.79
# ⋮   ⋮        ⋮          ⋮
# 76  56       AC_path    0.73
# 77  57       AC_path    0.74
# 78  58       AC_path    0.74
# 79  59       AC_path    0.74
# 80  60       AC_path    0.74
# 81  61       AC_path    0.74
# 82  62       AC_path    0.73
# 83  63       AC_path    0.74
# 84  64       AC_path    0.74
# 85  65       AC_path    0.74
# 86  66       AC_path    0.74
# 87  67       AC_path    0.74
# 88  68       AC_path    0.74
# 89  69       AC_path    0.74
# 90  70       AC_path    0.74
# 91  71       AC_path    0.74
# 92  72       AC_path    0.74
# 93  73       AC_path    0.74
# 94  74       AC_path    0.74
# 95  75       AC_path    0.73
# 96  76       AC_path    0.74
# 97  77       AC_path    0.74
# 98  78       AC_path    0.74
# 99  79       AC_path    0.74
# 100 80       AC_path    0.74
# 101 81       AC_path    0.74
# 102 82       AC_path    0.74
# 103 83       AC_path    0.74
# 104 84       AC_path    0.73
# 105 85       AC_path    0.74

# %%
clm = colnames(bh5)
sp = clm[-1]

# %%
ttl = "BAHA5P-group: CVC-score for the three sound paths, 
in the condition S at BCD-side and N in front"
ColorBlind3  <- c("#E69F00", "#56B4E9", "#009E73")

beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, main = ttl, ylim=c(0.6, 1))
ylabel = seq(0.6, 1, by = 0.05)
legend("bottomleft", legend = sp, title = "Sound-path", cex=1.1, pch = 16, col = ColorBlind3)
# Out:
# Plot with title “BAHA5P-group: CVC-score for the three sound paths,
# in the condition S at BCD-side and N in front”

# %%
tiff("/home/guido/R/cingle/figures/CVC_Sbcd_Nf.tiff", units="in", width=7, height=7, res=300)
beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, ylim=c(0.6, 1))
legend("bottomleft", legend = sp, title = "Sound-path", pch = 16, col = ColorBlind3, cex = 1.1)
dev.off()
# Out:
# png
#   2
