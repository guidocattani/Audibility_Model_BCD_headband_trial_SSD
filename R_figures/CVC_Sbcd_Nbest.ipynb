# %% [markdown]
# 30 March 2021 GC, R code to plot beeswarm

# %%
library("readxl")
library('data.table')
library("beeswarm")

# %%
read_CVC <- function(path_in) {
  dt <- read_excel(path_in)
  dt <- dt[ -c(1, 7)]
  bh5 <- subset(dt, Device=='BAHA5P')
  bh5 <- bh5[ -c(2)]
  bh5 <- bh5[, c(1, 4, 3, 2)]
  return(bh5)
}

# %%
path1 <- '/media/guido/LACIE/Cingle_Guido/Master/Headband/CVC_Sbcd65_Nbest65.xlsx'

# %%
bh5 <- read_CVC(path1)
bh5
# Out:
# New names:
# * `` -> ...1
#    Study_ID AC&BC_path BC_path AC_path
# 1  21       0.63       0.92    0.62
# 2  48       0.62       0.91    0.62
# 3  52       0.62       0.91    0.62
# 4  54       0.66       0.90    0.62
# 5  55       0.63       0.91    0.62
# 6  56       0.74       0.90    0.62
# 7  57       0.62       0.90    0.62
# 8  58       0.63       0.92    0.62
# 9  59       0.62       0.90    0.62
# 10 60       0.69       0.91    0.62
# 11 61       0.64       0.90    0.62
# 12 62       0.80       0.90    0.62
# 13 63       0.71       0.91    0.62
# 14 64       0.65       0.91    0.62
# 15 65       0.66       0.91    0.62
# 16 66       0.67       0.92    0.62
# 17 67       0.62       0.90    0.62
# 18 68       0.64       0.91    0.62
# 19 69       0.70       0.91    0.62
# 20 70       0.65       0.92    0.62
# 21 71       0.62       0.89    0.62
# 22 72       0.62       0.91    0.62
# 23 73       0.63       0.90    0.62
# 24 74       0.67       0.91    0.62
# 25 75       0.82       0.90    0.62
# 26 76       0.65       0.91    0.62
# 27 77       0.64       0.92    0.62
# 28 78       0.63       0.91    0.62
# 29 79       0.62       0.91    0.62
# 30 80       0.70       0.90    0.62
# 31 81       0.65       0.89    0.62
# 32 82       0.62       0.91    0.62
# 33 83       0.67       0.90    0.62
# 34 84       0.67       0.90    0.62
# 35 85       0.63       0.91    0.62

# %%
bh5_long <- melt(setDT(bh5), id.vars = c('Study_ID'), 
                 value.name = 'CVC_score', variable.name = 'Sound_path')
bh5_long
# Out:
#     Study_ID Sound_path CVC_score
# 1   21       AC&BC_path 0.63
# 2   48       AC&BC_path 0.62
# 3   52       AC&BC_path 0.62
# 4   54       AC&BC_path 0.66
# 5   55       AC&BC_path 0.63
# 6   56       AC&BC_path 0.74
# 7   57       AC&BC_path 0.62
# 8   58       AC&BC_path 0.63
# 9   59       AC&BC_path 0.62
# 10  60       AC&BC_path 0.69
# 11  61       AC&BC_path 0.64
# 12  62       AC&BC_path 0.80
# 13  63       AC&BC_path 0.71
# 14  64       AC&BC_path 0.65
# 15  65       AC&BC_path 0.66
# 16  66       AC&BC_path 0.67
# 17  67       AC&BC_path 0.62
# 18  68       AC&BC_path 0.64
# 19  69       AC&BC_path 0.70
# 20  70       AC&BC_path 0.65
# 21  71       AC&BC_path 0.62
# 22  72       AC&BC_path 0.62
# 23  73       AC&BC_path 0.63
# 24  74       AC&BC_path 0.67
# 25  75       AC&BC_path 0.82
# 26  76       AC&BC_path 0.65
# 27  77       AC&BC_path 0.64
# 28  78       AC&BC_path 0.63
# 29  79       AC&BC_path 0.62
# 30  80       AC&BC_path 0.70
# ⋮   ⋮        ⋮          ⋮
# 76  56       AC_path    0.62
# 77  57       AC_path    0.62
# 78  58       AC_path    0.62
# 79  59       AC_path    0.62
# 80  60       AC_path    0.62
# 81  61       AC_path    0.62
# 82  62       AC_path    0.62
# 83  63       AC_path    0.62
# 84  64       AC_path    0.62
# 85  65       AC_path    0.62
# 86  66       AC_path    0.62
# 87  67       AC_path    0.62
# 88  68       AC_path    0.62
# 89  69       AC_path    0.62
# 90  70       AC_path    0.62
# 91  71       AC_path    0.62
# 92  72       AC_path    0.62
# 93  73       AC_path    0.62
# 94  74       AC_path    0.62
# 95  75       AC_path    0.62
# 96  76       AC_path    0.62
# 97  77       AC_path    0.62
# 98  78       AC_path    0.62
# 99  79       AC_path    0.62
# 100 80       AC_path    0.62
# 101 81       AC_path    0.62
# 102 82       AC_path    0.62
# 103 83       AC_path    0.62
# 104 84       AC_path    0.62
# 105 85       AC_path    0.62

# %%
clm = colnames(bh5)
sp = clm[-1]

# %%
ttl = "BAHA5P-group: CVC-score for the three sound paths, 
in the condition S at BCD-side and N at best-ear-side"
ColorBlind3  <- c("#E69F00", "#56B4E9", "#009E73")
p <- beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
              ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, 
              main = ttl, 
              ylim=c(0, 1))
l <- legend("bottomleft", legend = sp, title = "Sound-path", cex=1.1, pch = 16, col = ColorBlind3)
# Out:
# Plot with title “BAHA5P-group: CVC-score for the three sound paths,
# in the condition S at BCD-side and N at best-ear-side”

# %%
tiff("/home/guido/R/cingle/figures/CVC_Sbcd_Nbe.tiff", units="in", width=7, height=7, res=300)
ColorBlind3  <- c("#E69F00", "#56B4E9", "#009E73")
beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, ylim=c(0, 1))
legend("bottomleft", legend = sp, title = "Sound-path", pch = 16, col = ColorBlind3, cex = 1.1)
dev.off()
# Out:
# png
#   2
