# %% [markdown]
# 30 March 2021 GC, R code to plot beeswarm

# %%
library("readxl")
library('data.table')
library("beeswarm")

# %%
read_CVC <- function(path_in) {
  dt <- read_excel(path_in)
  dt <- dt[ -c(1, 7)]
  bh5 <- subset(dt, Device=='BAHA5P')
  bh5 <- bh5[ -c(2)]
  bh5 <- bh5[, c(1, 4, 3, 2)]
  return(bh5)
}

# %%
path1 <- '/media/guido/LACIE/Cingle_Guido/Master/Headband/CVC_Sbest65_Nbcd65.xlsx'

# %%
bh5 <- read_CVC(path1)
bh5
# Out:
# New names:
# * `` -> ...1
#    Study_ID AC&BC_path BC_path AC_path
# 1  21       0.95       0.49    0.95
# 2  48       0.95       0.37    0.95
# 3  52       0.95       0.43    0.95
# 4  54       0.94       0.45    0.94
# 5  55       0.95       0.40    0.95
# 6  56       0.92       0.38    0.94
# 7  57       0.95       0.31    0.95
# 8  58       0.95       0.39    0.95
# 9  59       0.95       0.44    0.95
# 10 60       0.93       0.49    0.95
# 11 61       0.95       0.37    0.95
# 12 62       0.90       0.30    0.94
# 13 63       0.93       0.42    0.95
# 14 64       0.94       0.33    0.95
# 15 65       0.94       0.43    0.95
# 16 66       0.94       0.38    0.95
# 17 67       0.95       0.43    0.95
# 18 68       0.95       0.40    0.95
# 19 69       0.94       0.40    0.95
# 20 70       0.94       0.42    0.95
# 21 71       0.95       0.39    0.95
# 22 72       0.95       0.47    0.95
# 23 73       0.95       0.44    0.95
# 24 74       0.94       0.31    0.95
# 25 75       0.90       0.36    0.94
# 26 76       0.95       0.39    0.95
# 27 77       0.95       0.35    0.95
# 28 78       0.95       0.44    0.95
# 29 79       0.95       0.37    0.95
# 30 80       0.94       0.45    0.95
# 31 81       0.95       0.27    0.95
# 32 82       0.95       0.46    0.95
# 33 83       0.94       0.46    0.95
# 34 84       0.94       0.33    0.94
# 35 85       0.95       0.31    0.95

# %%
bh5_long <- melt(setDT(bh5), id.vars = c('Study_ID'), 
                 value.name = 'CVC_score', variable.name = 'Sound_path')
bh5_long
# Out:
#     Study_ID Sound_path CVC_score
# 1   21       AC&BC_path 0.95
# 2   48       AC&BC_path 0.95
# 3   52       AC&BC_path 0.95
# 4   54       AC&BC_path 0.94
# 5   55       AC&BC_path 0.95
# 6   56       AC&BC_path 0.92
# 7   57       AC&BC_path 0.95
# 8   58       AC&BC_path 0.95
# 9   59       AC&BC_path 0.95
# 10  60       AC&BC_path 0.93
# 11  61       AC&BC_path 0.95
# 12  62       AC&BC_path 0.90
# 13  63       AC&BC_path 0.93
# 14  64       AC&BC_path 0.94
# 15  65       AC&BC_path 0.94
# 16  66       AC&BC_path 0.94
# 17  67       AC&BC_path 0.95
# 18  68       AC&BC_path 0.95
# 19  69       AC&BC_path 0.94
# 20  70       AC&BC_path 0.94
# 21  71       AC&BC_path 0.95
# 22  72       AC&BC_path 0.95
# 23  73       AC&BC_path 0.95
# 24  74       AC&BC_path 0.94
# 25  75       AC&BC_path 0.90
# 26  76       AC&BC_path 0.95
# 27  77       AC&BC_path 0.95
# 28  78       AC&BC_path 0.95
# 29  79       AC&BC_path 0.95
# 30  80       AC&BC_path 0.94
# ⋮   ⋮        ⋮          ⋮
# 76  56       AC_path    0.94
# 77  57       AC_path    0.95
# 78  58       AC_path    0.95
# 79  59       AC_path    0.95
# 80  60       AC_path    0.95
# 81  61       AC_path    0.95
# 82  62       AC_path    0.94
# 83  63       AC_path    0.95
# 84  64       AC_path    0.95
# 85  65       AC_path    0.95
# 86  66       AC_path    0.95
# 87  67       AC_path    0.95
# 88  68       AC_path    0.95
# 89  69       AC_path    0.95
# 90  70       AC_path    0.95
# 91  71       AC_path    0.95
# 92  72       AC_path    0.95
# 93  73       AC_path    0.95
# 94  74       AC_path    0.95
# 95  75       AC_path    0.94
# 96  76       AC_path    0.95
# 97  77       AC_path    0.95
# 98  78       AC_path    0.95
# 99  79       AC_path    0.95
# 100 80       AC_path    0.95
# 101 81       AC_path    0.95
# 102 82       AC_path    0.95
# 103 83       AC_path    0.95
# 104 84       AC_path    0.94
# 105 85       AC_path    0.95

# %%
clm = colnames(bh5)
sp = clm[-1]

# %%
ttl = "BAHA5P-group: CVC-score for the three sound paths, 
in the condition S at best-ear-side and N at BCD-side"
ColorBlind3  <- c("#E69F00", "#56B4E9", "#009E73")
p <- beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, main = ttl, ylim=c(0, 1))
l <- legend("bottomleft", legend = sp, title = "Sound-path", cex=1.1, pch = 16, col = ColorBlind3)
# Out:
# Plot with title “BAHA5P-group: CVC-score for the three sound paths,
# in the condition S at best-ear-side and N at BCD-side”

# %%
tiff("/home/guido/R/cingle/figures/CVC_Sbe_Nbcd.tiff", units="in", width=7, height=7, res=300)
p <- beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, ylim=c(0, 1))
l <- legend("bottomleft", legend = sp, title = "Sound-path", cex=1.1, pch = 16, col = ColorBlind3)
dev.off()
# Out:
# png
#   2
