# %% [markdown]
# 30 March 2021 GC, R code to plot beeswarm

# %%
library("readxl")
library('data.table')
library("beeswarm")

# %%
read_CVC <- function(path_in) {
  dt <- read_excel(path_in)
  dt <- dt[ -c(1, 7)]
  bh5 <- subset(dt, Device=='BAHA5P')
  bh5 <- bh5[ -c(2)]
  bh5 <- bh5[, c(1, 4, 3, 2)]
  return(bh5)
}

# %%
path1 <- '/media/guido/LACIE/Cingle_Guido/Master/Headband/CVC_Sbest65_Nfront65.xlsx'

# %%
bh5 <- read_CVC(path1)
bh5
# Out:
# New names:
# * `` -> ...1
#    Study_ID AC&BC_path BC_path AC_path
# 1  21       0.91       0.65    0.91
# 2  48       0.91       0.60    0.91
# 3  52       0.91       0.62    0.91
# 4  54       0.90       0.61    0.90
# 5  55       0.91       0.61    0.91
# 6  56       0.89       0.60    0.90
# 7  57       0.91       0.55    0.91
# 8  58       0.91       0.63    0.91
# 9  59       0.91       0.62    0.91
# 10 60       0.90       0.65    0.91
# 11 61       0.91       0.59    0.91
# 12 62       0.88       0.55    0.90
# 13 63       0.91       0.62    0.91
# 14 64       0.91       0.55    0.91
# 15 65       0.91       0.63    0.91
# 16 66       0.91       0.60    0.91
# 17 67       0.91       0.60    0.91
# 18 68       0.91       0.60    0.91
# 19 69       0.90       0.61    0.91
# 20 70       0.91       0.63    0.91
# 21 71       0.91       0.58    0.91
# 22 72       0.91       0.63    0.91
# 23 73       0.91       0.62    0.91
# 24 74       0.91       0.57    0.91
# 25 75       0.88       0.57    0.90
# 26 76       0.91       0.60    0.91
# 27 77       0.91       0.61    0.91
# 28 78       0.91       0.64    0.91
# 29 79       0.91       0.61    0.91
# 30 80       0.90       0.60    0.91
# 31 81       0.91       0.51    0.91
# 32 82       0.91       0.62    0.91
# 33 83       0.91       0.61    0.91
# 34 84       0.90       0.56    0.90
# 35 85       0.91       0.55    0.91

# %%
bh5_long <- melt(setDT(bh5), id.vars = c('Study_ID'), 
                 value.name = 'CVC_score', variable.name = 'Sound_path')
bh5_long
# Out:
#     Study_ID Sound_path CVC_score
# 1   21       AC&BC_path 0.91
# 2   48       AC&BC_path 0.91
# 3   52       AC&BC_path 0.91
# 4   54       AC&BC_path 0.90
# 5   55       AC&BC_path 0.91
# 6   56       AC&BC_path 0.89
# 7   57       AC&BC_path 0.91
# 8   58       AC&BC_path 0.91
# 9   59       AC&BC_path 0.91
# 10  60       AC&BC_path 0.90
# 11  61       AC&BC_path 0.91
# 12  62       AC&BC_path 0.88
# 13  63       AC&BC_path 0.91
# 14  64       AC&BC_path 0.91
# 15  65       AC&BC_path 0.91
# 16  66       AC&BC_path 0.91
# 17  67       AC&BC_path 0.91
# 18  68       AC&BC_path 0.91
# 19  69       AC&BC_path 0.90
# 20  70       AC&BC_path 0.91
# 21  71       AC&BC_path 0.91
# 22  72       AC&BC_path 0.91
# 23  73       AC&BC_path 0.91
# 24  74       AC&BC_path 0.91
# 25  75       AC&BC_path 0.88
# 26  76       AC&BC_path 0.91
# 27  77       AC&BC_path 0.91
# 28  78       AC&BC_path 0.91
# 29  79       AC&BC_path 0.91
# 30  80       AC&BC_path 0.90
# ⋮   ⋮        ⋮          ⋮
# 76  56       AC_path    0.90
# 77  57       AC_path    0.91
# 78  58       AC_path    0.91
# 79  59       AC_path    0.91
# 80  60       AC_path    0.91
# 81  61       AC_path    0.91
# 82  62       AC_path    0.90
# 83  63       AC_path    0.91
# 84  64       AC_path    0.91
# 85  65       AC_path    0.91
# 86  66       AC_path    0.91
# 87  67       AC_path    0.91
# 88  68       AC_path    0.91
# 89  69       AC_path    0.91
# 90  70       AC_path    0.91
# 91  71       AC_path    0.91
# 92  72       AC_path    0.91
# 93  73       AC_path    0.91
# 94  74       AC_path    0.91
# 95  75       AC_path    0.90
# 96  76       AC_path    0.91
# 97  77       AC_path    0.91
# 98  78       AC_path    0.91
# 99  79       AC_path    0.91
# 100 80       AC_path    0.91
# 101 81       AC_path    0.91
# 102 82       AC_path    0.91
# 103 83       AC_path    0.91
# 104 84       AC_path    0.90
# 105 85       AC_path    0.91

# %%
clm = colnames(bh5)
sp = clm[-1]

# %%
ttl = "BAHA5P-group: CVC-score for the three sound paths, 
in the condition S at best-ear-side and N in front"
ColorBlind3  <- c("#E69F00", "#56B4E9", "#009E73")
p <- beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, main = ttl, ylim=c(0, 1))
l <- legend("bottomleft", legend = sp, title = "Sound-path", cex=1.1, pch = 16, col = ColorBlind3)
# Out:
# Plot with title “BAHA5P-group: CVC-score for the three sound paths,
# in the condition S at best-ear-side and N in front”

# %%
tiff("/home/guido/R/cingle/figures/CVC_Sbe_Nf.tiff", units="in", width=7, height=7, res=300)
p <- beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, ylim=c(0, 1))
l <- legend("bottomleft", legend = sp, title = "Sound-path", cex=1.1, pch = 16, col = ColorBlind3)
dev.off()
# Out:
# png
#   2
