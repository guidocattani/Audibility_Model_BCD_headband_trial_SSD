# %% [markdown]
# 30 March 2021 GC, R code to plot beeswarm

# %%
library("readxl")
library('data.table')
library("beeswarm")

# %%
read_CVC <- function(path_in) {
  dt <- read_excel(path_in)
  dt <- dt[ -c(1, 7)]
  bh5 <- subset(dt, Device=='BAHA5P')
  bh5 <- bh5[ -c(2)]
  bh5 <- bh5[, c(1, 4, 3, 2)]
  return(bh5)
}

# %%
path1 <- '/media/guido/LACIE/Cingle_Guido/Master/Headband/CVC_Sbest65_silence.xlsx'

# %%
bh5 <- read_CVC(path1)
bh5
# Out:
# New names:
# * `` -> ...1
#    Study_ID AC&BC_path BC_path AC_path
# 1  21       0.98       0.96    0.98
# 2  48       0.98       0.96    0.98
# 3  52       0.98       0.96    0.98
# 4  54       0.98       0.96    0.98
# 5  55       0.98       0.96    0.98
# 6  56       0.98       0.95    0.98
# 7  57       0.98       0.95    0.98
# 8  58       0.98       0.97    0.98
# 9  59       0.98       0.96    0.98
# 10 60       0.98       0.97    0.98
# 11 61       0.98       0.94    0.98
# 12 62       0.98       0.95    0.98
# 13 63       0.98       0.96    0.98
# 14 64       0.98       0.97    0.98
# 15 65       0.98       0.97    0.98
# 16 66       0.98       0.97    0.98
# 17 67       0.98       0.96    0.98
# 18 68       0.98       0.96    0.98
# 19 69       0.98       0.96    0.98
# 20 70       0.98       0.97    0.98
# 21 71       0.98       0.95    0.98
# 22 72       0.98       0.96    0.98
# 23 73       0.98       0.96    0.98
# 24 74       0.98       0.96    0.98
# 25 75       0.98       0.96    0.98
# 26 76       0.98       0.96    0.98
# 27 77       0.98       0.96    0.98
# 28 78       0.98       0.97    0.98
# 29 79       0.98       0.96    0.98
# 30 80       0.98       0.96    0.98
# 31 81       0.98       0.95    0.98
# 32 82       0.98       0.96    0.98
# 33 83       0.98       0.96    0.98
# 34 84       0.98       0.94    0.98
# 35 85       0.98       0.96    0.98

# %%
bh5_long <- melt(setDT(bh5), id.vars = c('Study_ID'), 
                 value.name = 'CVC_score', variable.name = 'Sound_path')
bh5_long
# Out:
#     Study_ID Sound_path CVC_score
# 1   21       AC&BC_path 0.98
# 2   48       AC&BC_path 0.98
# 3   52       AC&BC_path 0.98
# 4   54       AC&BC_path 0.98
# 5   55       AC&BC_path 0.98
# 6   56       AC&BC_path 0.98
# 7   57       AC&BC_path 0.98
# 8   58       AC&BC_path 0.98
# 9   59       AC&BC_path 0.98
# 10  60       AC&BC_path 0.98
# 11  61       AC&BC_path 0.98
# 12  62       AC&BC_path 0.98
# 13  63       AC&BC_path 0.98
# 14  64       AC&BC_path 0.98
# 15  65       AC&BC_path 0.98
# 16  66       AC&BC_path 0.98
# 17  67       AC&BC_path 0.98
# 18  68       AC&BC_path 0.98
# 19  69       AC&BC_path 0.98
# 20  70       AC&BC_path 0.98
# 21  71       AC&BC_path 0.98
# 22  72       AC&BC_path 0.98
# 23  73       AC&BC_path 0.98
# 24  74       AC&BC_path 0.98
# 25  75       AC&BC_path 0.98
# 26  76       AC&BC_path 0.98
# 27  77       AC&BC_path 0.98
# 28  78       AC&BC_path 0.98
# 29  79       AC&BC_path 0.98
# 30  80       AC&BC_path 0.98
# ⋮   ⋮        ⋮          ⋮
# 76  56       AC_path    0.98
# 77  57       AC_path    0.98
# 78  58       AC_path    0.98
# 79  59       AC_path    0.98
# 80  60       AC_path    0.98
# 81  61       AC_path    0.98
# 82  62       AC_path    0.98
# 83  63       AC_path    0.98
# 84  64       AC_path    0.98
# 85  65       AC_path    0.98
# 86  66       AC_path    0.98
# 87  67       AC_path    0.98
# 88  68       AC_path    0.98
# 89  69       AC_path    0.98
# 90  70       AC_path    0.98
# 91  71       AC_path    0.98
# 92  72       AC_path    0.98
# 93  73       AC_path    0.98
# 94  74       AC_path    0.98
# 95  75       AC_path    0.98
# 96  76       AC_path    0.98
# 97  77       AC_path    0.98
# 98  78       AC_path    0.98
# 99  79       AC_path    0.98
# 100 80       AC_path    0.98
# 101 81       AC_path    0.98
# 102 82       AC_path    0.98
# 103 83       AC_path    0.98
# 104 84       AC_path    0.98
# 105 85       AC_path    0.98

# %%
clm = colnames(bh5)
sp = clm[-1]

# %%
ttl = "BAHA5P-group: CVC-score for the three sound paths, 
in the condition in silence, with S at best-ear-side"
ColorBlind3  <- c("#E69F00", "#56B4E9", "#009E73")
p <- beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, main = ttl, ylim=c(0, 1))
l <- legend("bottomleft", legend = sp, title = "Sound-path", cex=1.1, pch = 16, col = ColorBlind3)
# Out:
# Plot with title “BAHA5P-group: CVC-score for the three sound paths,
# in the condition in silence, with S at best-ear-side”

# %%
tiff("/home/guido/R/cingle/figures/CVC_Sbe_Nnone.tiff", units="in", width=7, height=7, res=300)
p <- beeswarm(CVC_score ~ Sound_path, data = bh5_long, pch = 16, col = ColorBlind3, 
         ylab = "CVC-score", xlab = "Sound-path", cex.lab=1.4, ylim=c(0, 1))
l <- legend("bottomleft", legend = sp, title = "Sound-path", cex=1.1, pch = 16, col = ColorBlind3)
dev.off()
# Out:
# png
#   2
