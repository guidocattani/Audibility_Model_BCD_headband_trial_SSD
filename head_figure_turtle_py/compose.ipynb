# %%
# import pillow
from PIL import Image

# %%
im1 = Image.open('/home/guido/R/cingle/figures/with_head/diff_SL_bcd_BH5.tiff')
im2 = Image.open('/media/guido/LACIE/Cingle_Guido/turtle_head_figures/cropped/lines.tiff')

# %%
back_im = im1.copy()
back_im.paste(im2, (1485, 962))

# %%
back_im.show()

# %%
back_im.save('/home/guido/R/cingle/figures/with_head/legend/diff_SL_bcd_BH5.tiff', quality=95)

# %%
print('Done!')
# Out:
# Done!
